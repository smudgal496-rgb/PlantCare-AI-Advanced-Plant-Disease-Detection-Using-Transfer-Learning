# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input

# %%
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
SEED = 1337

# %%
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    horizontal_flip=True,
    rotation_range=20,
    zoom_range=0.15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    fill_mode="reflect"
)

# %%
valid_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

# %%
train_dir = "/content/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train"
valid_dir = "/content/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/valid"

# %%
train_dir = "/content/new plant diseases dataset(augmented)/New Plant Diseases Dataset(Augmented)/train"

valid_dir = "/content/new plant diseases dataset(augmented)/New Plant Diseases Dataset(Augmented)/valid"

# %%
train_dir = r"/content/new plant diseases dataset(augmented)/New Plant Diseases Dataset(Augmented)/train"
valid_dir = r"/content/new plant diseases dataset(augmented)/New Plant Diseases Dataset(Augmented)/valid"

# %%
import os
print(os.path.exists(train_dir))
print(os.path.exists(valid_dir))
# Out:
# False
# False
