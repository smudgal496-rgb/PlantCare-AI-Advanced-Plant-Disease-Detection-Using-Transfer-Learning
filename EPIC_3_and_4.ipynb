# %%
#__ACTIVITY 3.1__
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers
from tensorflow.keras.applications import MobileNetV2

# 1. Setup Parameters (Based on your Activity 11 & 12)
IMG_SHAPE = (224, 224, 3)
NUM_CLASSES = 38  # Your dataset has 38 classes

# 2. Re-create the Model (Fixes NameError)
base_model = MobileNetV2(input_shape=IMG_SHAPE, include_top=False, weights='imagenet')
base_model.trainable = False  # Freeze base layers for Phase 1

model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(NUM_CLASSES, activation='softmax')
])

# 3. Compile the Model
model.compile(
    optimizer=optimizers.Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

print("Model fixed, defined, and compiled successfully!")
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Model fixed, defined, and compiled successfully!
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ mobilenetv2_1.00_224            │ (None, 7, 7, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 38)             │         9,766 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,595,686 (9.90 MB)
#  Trainable params: 337,702 (1.29 MB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %%
#__ACTIVITY 3.2__
import tensorflow as tf
from tensorflow import keras

# Define training callbacks
callbacks = [
    # 1. Save best model based on validation accuracy
    keras.callbacks.ModelCheckpoint(
        "plant_care_model_best.keras",
        monitor='val_accuracy',
        save_best_only=True,
        verbose=1
    ),

    # 2. Reduce learning rate when validation loss plateaus
    keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=3,
        verbose=1
    ),

    # 3. Stop training if no improvement (Prevents overfitting)
    keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=6,
        restore_best_weights=True,
        verbose=1
    )
]

print("Callbacks configured successfully:")
print("  1. ModelCheckpoint - Will save to 'plant_care_model_best.keras'")
print("  2. ReduceLROnPlateau - Will drop learning rate if val_loss stalls")
print("  3. EarlyStopping - Will end training if the model stops improving")
# Out:
# Callbacks configured successfully:
#   1. ModelCheckpoint - Will save to 'plant_care_model_best.keras'
#   2. ReduceLROnPlateau - Will drop learning rate if val_loss stalls
#   3. EarlyStopping - Will end training if the model stops improving

# %%
#__ACTIVITY 3.3__
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, optimizers
import os
import kagglehub

# --- 1. DOWNLOAD AND DYNAMICALLY LOCATE DATASET ---
# This downloads the dataset and returns the local path on the Colab server
base_path = kagglehub.dataset_download("vipoooool/new-plant-diseases-dataset")

# Use os.path.join to build the correct Linux paths for Colab
# Based on the dataset structure, we add the subfolders:
train_dir = os.path.join(base_path, "New Plant Diseases Dataset(Augmented)", "New Plant Diseases Dataset(Augmented)", "train")
valid_dir = os.path.join(base_path, "New Plant Diseases Dataset(Augmented)", "New Plant Diseases Dataset(Augmented)", "valid")

# Verify the paths exist before loading
if os.path.exists(train_dir):
    print(f"✅ Found training directory at: {train_dir}")
else:
    # If the subfolder names are slightly different, list the directory to see them
    print("❌ Path error. Actual folders in download:", os.listdir(base_path))

# --- 2. LOAD DATASETS ---
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir,
    image_size=(224, 224),
    batch_size=32,
    label_mode='categorical'
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    valid_dir,
    image_size=(224, 224),
    batch_size=32,
    label_mode='categorical'
)

# --- 3. TRAIN THE MODEL ---
# (Ensure your Activity 3.1 model and 3.2 callbacks are defined)
print("\n🚀 Starting Phase 1 Training...")
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=10,
    callbacks=callbacks
)
# Out:
# Using Colab cache for faster access to the 'new-plant-diseases-dataset' dataset.
# ✅ Found training directory at: /kaggle/input/new-plant-diseases-dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train
# Found 70295 files belonging to 38 classes.
# Found 17572 files belonging to 38 classes.
#
# 🚀 Starting Phase 1 Training...
# Epoch 1/10
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2642 - loss: 2.7723
# Epoch 1: val_accuracy improved from -inf to 0.67078, saving model to plant_care_model_best.keras
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 3804s 2s/step - accuracy: 0.2643 - loss: 2.7720 - val_accuracy: 0.6708 - val_loss: 1.3280 - learning_rate: 1.0000e-04
# Epoch 2/10
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5786 - loss: 1.4779
# Epoch 2: val_accuracy improved from 0.67078 to 0.72957, saving model to plant_care_model_best.keras
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 3829s 2s/step - accuracy: 0.5786 - loss: 1.4779 - val_accuracy: 0.7296 - val_loss: 1.0057 - learning_rate: 1.0000e-04
# Epoch 3/10
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6519 - loss: 1.1878
# Epoch 3: val_accuracy improved from 0.72957 to 0.76138, saving model to plant_care_model_best.keras
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 3718s 2s/step - accuracy: 0.6519 - loss: 1.1878 - val_accuracy: 0.7614 - val_loss: 0.8634 - learning_rate: 1.0000e-04
# Epoch 4/10
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6944 - loss: 1.0322
# Epoch 4: val_accuracy improved from 0.76138 to 0.77942, saving model to plant_care_model_best.keras
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 3673s 2s/step - accuracy: 0.6944 - loss: 1.0322 - val_accuracy: 0.7794 - val_loss: 0.7718 - learning_rate: 1.0000e-04
# Epoch 5/10
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7172 - loss: 0.9422
# Epoch 5: val_accuracy improved from 0.77942 to 0.79188, saving model to plant_care_model_best.keras
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 3680s 2s/step - accuracy: 0.7172 - loss: 0.9422 - val_accuracy: 0.7919 - val_loss: 0.7194 - learning_rate: 1.0000e-04
# Epoch 6/10
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7367 - loss: 0.8713
# Epoch 6: val_accuracy improved from 0.79188 to 0.80145, saving model to plant_care_model_best.keras
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 3739s 2s/step - accuracy: 0.7367 - loss: 0.8712 - val_accuracy: 0.8014 - val_loss: 0.6689 - learning_rate: 1.0000e-04
# Epoch 7/10
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7525 - loss: 0.8162
# Epoch 7: val_accuracy improved from 0.80145 to 0.81152, saving model to plant_care_model_best.keras
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 3686s 2s/step - accuracy: 0.7525 - loss: 0.8161 - val_accuracy: 0.8115 - val_loss: 0.6334 - learning_rate: 1.0000e-04
# Epoch 8/10
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7660 - loss: 0.7722
# Epoch 8: val_accuracy improved from 0.81152 to 0.81840, saving model to plant_care_model_best.keras
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 3696s 2s/step - accuracy: 0.7660 - loss: 0.7722 - val_accuracy: 0.8184 - val_loss: 0.6048 - learning_rate: 1.0000e-04
# Epoch 9/10
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7732 - loss: 0.7361
# Epoch 9: val_accuracy improved from 0.81840 to 0.82296, saving model to plant_care_model_best.keras
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 3764s 2s/step - accuracy: 0.7732 - loss: 0.7361 - val_accuracy: 0.8230 - val_loss: 0.5839 - learning_rate: 1.0000e-04
# Epoch 10/10
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7832 - loss: 0.7027
# Epoch 10: val_accuracy improved from 0.82296 to 0.82762, saving model to plant_care_model_best.keras
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 3827s 2s/step - accuracy: 0.7832 - loss: 0.7027 - val_accuracy: 0.8276 - val_loss: 0.5629 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 10.

# %%
#__ACTIVITY 3.4__
import matplotlib.pyplot as plt

# ---------------- Plot training curves ----------------
plt.figure(figsize=(12,4))

# Accuracy Plot
plt.subplot(1,2,1)
plt.plot(history.history.get('accuracy', []), label='train_accuracy')
plt.plot(history.history.get('val_accuracy', []), label='val_accuracy')
plt.xlabel('epoch'); plt.ylabel('accuracy'); plt.legend(); plt.title('Accuracy')

# Loss Plot
plt.subplot(1,2,2)
plt.plot(history.history.get('loss', []), label='train_loss')
plt.plot(history.history.get('val_loss', []), label='val_loss')
plt.xlabel('epoch'); plt.ylabel('loss'); plt.legend(); plt.title('Loss')

plt.show()

# %%
import os
import tensorflow as tf
import kagglehub

# 1. Get the path where kagglehub previously downloaded the data
base_path = kagglehub.dataset_download("vipoooool/new-plant-diseases-dataset")

# 2. Re-establish the directory paths
valid_dir = os.path.join(base_path, "New Plant Diseases Dataset(Augmented)", "New Plant Diseases Dataset(Augmented)", "valid")

# 3. Re-load the validation dataset (This defines 'val_ds')
print("Loading Validation Dataset into memory...")
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    valid_dir,
    image_size=(224, 224),
    batch_size=32,
    label_mode='categorical'
)

print(f"✅ 'val_ds' is now defined with {len(val_ds.class_names)} classes.")
# Out:
# Using Colab cache for faster access to the 'new-plant-diseases-dataset' dataset.
# Loading Validation Dataset into memory...
# Found 17572 files belonging to 38 classes.
# ✅ 'val_ds' is now defined with 38 classes.

# %%
#__ACTIVITY 4.1__
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# --- Activity 4.1: Detailed Evaluation ---

print("Step 1: Generating Predictions (this may take a minute)...")

# 1. Get the true labels and predictions
# We use the validation dataset to see how it performs on "unseen" data
y_true = []
y_pred = []

for images, labels in val_ds:
    preds = model.predict(images, verbose=0)
    y_true.extend(np.argmax(labels, axis=1))
    y_pred.extend(np.argmax(preds, axis=1))

# 2. Get the Class Names from the dataset
class_names = val_ds.class_names

# 3. Print the Classification Report (Precision, Recall, F1-Score)
print("\n--- Classification Report ---")
print(classification_report(y_true, y_pred, target_names=class_names))

# 4. Plot the Confusion Matrix
print("\n--- Generating Confusion Matrix ---")
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(20, 20))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix: Plant Disease Detection')
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')
plt.show()
# Out:
# Step 1: Generating Predictions (this may take a minute)...
#
# --- Classification Report ---
#                                                     precision    recall  f1-score   support
#
#                                 Apple___Apple_scab       0.00      0.00      0.00       504
#                                  Apple___Black_rot       0.02      0.56      0.04       497
#                           Apple___Cedar_apple_rust       0.02      0.03      0.02       440
#                                    Apple___healthy       0.00      0.00      0.00       502
#                                Blueberry___healthy       0.00      0.00      0.00       454
#           Cherry_(including_sour)___Powdery_mildew       0.00      0.00      0.00       421
#                  Cherry_(including_sour)___healthy       0.00      0.00      0.00       456
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot       0.00      0.00      0.00       410
#                        Corn_(maize)___Common_rust_       0.00      0.00      0.00       477
#                Corn_(maize)___Northern_Leaf_Blight       0.00      0.00      0.00       477
#                             Corn_(maize)___healthy       0.00      0.00      0.00       465
#                                  Grape___Black_rot       0.00      0.00      0.00       472
#                       Grape___Esca_(Black_Measles)       0.00      0.00      0.00       480
#         Grape___Leaf_blight_(Isariopsis_Leaf_Spot)       0.00      0.00      0.00       430
#                                    Grape___healthy       0.00      0.00      0.00       423
#           Orange___Haunglongbing_(Citrus_greening)       0.00      0.01      0.00       503
#                             Peach___Bacterial_spot       0.00      0.00      0.00       459
#                                    Peach___healthy       0.00      0.00      0.00       432
#                      Pepper,_bell___Bacterial_spot       0.00      0.00      0.00       478
#                             Pepper,_bell___healthy       0.00      0.00      0.00       497
#                              Potato___Early_blight       0.00      0.00      0.00       485
#                               Potato___Late_blight       0.00      0.00      0.00       485
#                                   Potato___healthy       0.00      0.00      0.00       456
#                                Raspberry___healthy       0.07      0.01      0.02       445
#                                  Soybean___healthy       0.00      0.00      0.00       505
#                            Squash___Powdery_mildew       0.00      0.00      0.00       434
#                           Strawberry___Leaf_scorch       0.00      0.00      0.00       444
#                               Strawberry___healthy       0.00      0.00      0.00       456
#                            Tomato___Bacterial_spot       0.00      0.00      0.00       425
#                              Tomato___Early_blight       0.00      0.00      0.00       480
#                               Tomato___Late_blight       0.20      0.00      0.00       463
#                                 Tomato___Leaf_Mold       0.00      0.00      0.00       470
#                        Tomato___Septoria_leaf_spot       0.05      0.00      0.00       436
#      Tomato___Spider_mites Two-spotted_spider_mite       0.00      0.00      0.00       435
#                               Tomato___Target_Spot       0.00      0.00      0.00       457
#             Tomato___Tomato_Yellow_Leaf_Curl_Virus       0.00      0.00      0.00       490
#                       Tomato___Tomato_mosaic_virus       0.00      0.00      0.00       448
#                                   Tomato___healthy       0.04      0.01      0.02       481
#
#                                           accuracy                           0.02     17572
#                                          macro avg       0.01      0.02      0.00     17572
#                                       weighted avg       0.01      0.02      0.00     17572
#
#
# --- Generating Confusion Matrix ---
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
#__ACTIVITY 4.2__
import tensorflow as tf
from google.colab import files

# 1. Save the model to the Colab disk
# We use the .keras extension for the modern Keras 3 format
model_name = "plant_disease_model_final.keras"
model.save(model_name)

print(f"✅ Model saved successfully as {model_name}")

# 2. Download the model to your local computer
# This ensures you don't lose your work when Colab shuts down
print("Preparing download to your local machine...")
files.download(model_name)
# Out:
# ✅ Model saved successfully as plant_disease_model_final.keras
# Preparing download to your local machine...
